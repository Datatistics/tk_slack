# %% [raw]
# ---
# output-file: metadata_handler.html
# title: metadata_handler
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(MessageMetadataHandler)
# Out:
# ---
#
# [source](https://github.com/Datatistics/tk_slack/blob/main/tk_slack/metadata_handler.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### MessageMetadataHandler
#
# >      MessageMetadataHandler ()
#
# *Handles the creation and attachment of metadata to Slack messages.
#
# This class implements Slack's message metadata feature which allows
# attaching invisible structured data to messages for event-driven processing.
#
# Reference: https://api.slack.com/metadata*

# %%
#| echo: false
#| output: asis
show_doc(MessageMetadataHandler.create_metadata)
# Out:
# ---
#
# [source](https://github.com/Datatistics/tk_slack/blob/main/tk_slack/metadata_handler.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### MessageMetadataHandler.create_metadata
#
# >      MessageMetadataHandler.create_metadata (event_type:str,
# >                                              view_info:Optional[Dict[str,Any]]
# >                                              =None, response_config:Optional[D
# >                                              ict[str,Any]]=None, custom_data:O
# >                                              ptional[Dict[str,Any]]=None)
#
# *Create structured metadata for a Slack message.
#
# Args:
#     event_type: Type of event (e.g., 'lead_alert', 'data_notification')
#     view_info: Optional information about the view that generated this message
#     response_config: Optional configuration for how to respond to user actions
#     custom_data: Optional additional custom data to include
#
# Returns:
# ...

# %%
#| echo: false
#| output: asis
show_doc(MessageMetadataHandler.add_metadata_to_message)
# Out:
# ---
#
# [source](https://github.com/Datatistics/tk_slack/blob/main/tk_slack/metadata_handler.py#L80){target="_blank" style="float:right; font-size:smaller"}
#
# ### MessageMetadataHandler.add_metadata_to_message
#
# >      MessageMetadataHandler.add_metadata_to_message (message:Dict[str,Any],
# >                                                      event_type:str, view_info
# >                                                      :Optional[Dict[str,Any]]=
# >                                                      None, response_config:Opt
# >                                                      ional[Dict[str,Any]]=None
# >                                                      , custom_data:Optional[Di
# >                                                      ct[str,Any]]=None)
#
# *Add metadata to a Slack message payload.
#
# Args:
#     message: Slack message payload
#     event_type: Type of event
#     view_info: Optional view information
# ...

# %%
#| echo: false
#| output: asis
show_doc(MessageMetadataHandler.extract_metadata_from_message)
# Out:
# ---
#
# [source](https://github.com/Datatistics/tk_slack/blob/main/tk_slack/metadata_handler.py#L114){target="_blank" style="float:right; font-size:smaller"}
#
# ### MessageMetadataHandler.extract_metadata_from_message
#
# >      MessageMetadataHandler.extract_metadata_from_message
# >                                                            (message:Dict[str,A
# >                                                            ny])
#
# *Extract metadata from a Slack message.
#
# Args:
#     message: Slack message with metadata
#
# Returns:
#     Extracted metadata or empty dict if none*

# %%
#| echo: false
#| output: asis
show_doc(MessageMetadataHandler.get_event_payload)
# Out:
# ---
#
# [source](https://github.com/Datatistics/tk_slack/blob/main/tk_slack/metadata_handler.py#L130){target="_blank" style="float:right; font-size:smaller"}
#
# ### MessageMetadataHandler.get_event_payload
#
# >      MessageMetadataHandler.get_event_payload (message:Dict[str,Any])
#
# *Get the event payload from a message's metadata.
#
# Args:
#     message: Slack message with metadata
#
# Returns:
#     Event payload or empty dict if none*
